# %% [markdown]
# This file is used to preprocess the data and extract it

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils

# %%
movies_data_path = "../data/movies.csv"
ratings_data_path = "../data/ratings.csv"

# %%
df_movies = utils.init_traitement_DB(movies_data_path)
df_ratings = utils.init_traitement_DB(ratings_data_path)

# %%
# Shapes of the dataframes
print("Movies dataframe shape: ", df_movies.shape)
print("Ratings dataframe shape: ", df_ratings.shape)
# Out:
# Movies dataframe shape:  (62423, 3)
# Ratings dataframe shape:  (25000095, 4)

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
# Vérifier les valeurs manquantes
print(df_movies.isnull().sum())
print(df_ratings.isnull().sum())
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
genre_counts = utils.process_movies(df_movies)
print(genre_counts)
# Out:
# Adventure       4145
# Animation       2929
# Children        2935
# Comedy         16870
# Fantasy         2731
# Romance         7719
# Drama          25606
# Action          7348
# Crime           5319
# Thriller        8654
# Horror          5989
# Mystery         2925
# Sci-Fi          3595
# IMAX             195
# Documentary     5605
# War             1874
# Musical         1054
# Western         1399
# Film-Noir        353
# dtype: int64

# %%
utils.visualize_genre_distribution(df_movies,values=True, save=True)
# Out:
# /home/lvl/Desktop/github/Science_des_donnees_TP3/src/utils.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.text(i, genre_counts[i], genre_counts[i], ha='center', va='bottom')

# %%
df_movies = utils.init_traitement_DB(movies_data_path)
df_ratings = utils.init_traitement_DB(ratings_data_path)

utils.clean_and_save_data(df_movies=df_movies, df_ratings=df_ratings)
# Out:
# Les fichiers movies1.csv et ratings1.csv ont été créés avec succès.

# %%
movies_1_data_path = "../data/movies1.csv"
ratings_1_data_path = "../data/ratings1.csv"
df_movies_1 = utils.init_traitement_DB(movies_1_data_path)
ratings_1_data_path = utils.init_traitement_DB(ratings_1_data_path)
